# %% [markdown]
# # Random Forest model to predict MVP

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import RandomizedSearchCV
import os
import joblib
import pickle

# %% [markdown]
# ### Load data, select appropriate variables

# %%
df = pd.read_csv("mvp_data.csv", index_col=0).reset_index(drop=True)
df = df.fillna(0)
df.columns
# Out:
# Index(['Year', 'Player', 'Tm', 'Share', 'G', 'MP', 'PTS', 'TRB', 'AST', 'STL',
#        'BLK', 'FG%', '3P%', 'FT%', 'WS', 'WS/48', 'MVP',
#        'player_efficiency_rating', 'true_shooting_percentage',
#        'three_point_attempt_rate', 'free_throw_attempt_rate',
#        'offensive_rebound_percentage', 'defensive_rebound_percentage',
#        'total_rebound_percentage', 'assist_percentage', 'steal_percentage',
#        'block_percentage', 'turnover_percentage', 'usage_percentage',
#        'offensive_win_shares', 'defensive_win_shares',
#        'offensive_box_plus_minus', 'defensive_box_plus_minus',
#        'box_plus_minus', 'value_over_replacement_player', 'wl_pct', 'seed',
#        'highest_teammate_vorp', 'highest_teammate_ws'],
#       dtype='object')

# %%
# define points+rebounds+assists variable
df['PRA'] = df['PTS'] + df['TRB'] + df['AST']

# %%
# select variables used for regression (mutual_info from lin_reg model)
cols = ['PRA', 'WS/48', 'player_efficiency_rating', 'offensive_box_plus_minus',
       'value_over_replacement_player', 'wl_pct', 'seed']
X = df[cols]
y = df['Share']

# %% [markdown]
# ### Random Forest model with entire data

# %%
rf = RandomForestRegressor(max_depth=20, max_features=5)
rf.fit(X, y)
# Out:
# RandomForestRegressor(max_depth=20, max_features=5)

# %%
# Feature importance
for score, name in zip(rf.feature_importances_, X.columns):
    print(round(score, 2), name)
# Out:
# 0.14 PRA
# 0.16 WS/48
# 0.12 player_efficiency_rating
# 0.05 offensive_box_plus_minus
# 0.32 value_over_replacement_player
# 0.12 wl_pct
# 0.08 seed

# %% [markdown]
# ### Holdout single year as test set

# %%
df_train = df[df['Year'] != 2023]
df_test = df[df['Year'] == 2023]
X_train = df_train[cols]
y_train = df_train['Share']
X_test =  df_test[cols]
y_test = df_test['Share']

# %%
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
pred = rf.predict(X_test)

# %% [markdown]
# ### Evaluate with R2, MSE

# %%
r2_score(y_test, pred)
# Out:
# 0.6452739475532814

# %%
mean_squared_error(y_test, pred)
# Out:
# 0.03785261840999999

# %%
results = pd.DataFrame(y_test)
results['prediction'] = pred
results.index = df_test['Player']
results
# Out:
#                          Share  prediction
# Player
# Joel Embiid              0.915     0.54993
# Nikola Jokić             0.674     0.83154
# Giannis Antetokounmpo    0.606     0.53792
# Jayson Tatum             0.280     0.26145
# Shai Gilgeous-Alexander  0.046     0.11328
# Donovan Mitchell         0.030     0.09478
# Domantas Sabonis         0.027     0.20066
# Luka Dončić              0.010     0.38181
# Stephen Curry            0.005     0.09591
# Jimmy Butler             0.003     0.17639

# %%
# random search to select best hyperparameters
rf = RandomForestRegressor()

params = {
    'max_depth': list(range(5, 35, 5)),
    'max_features': list(range(3,8,1)),
    'min_samples_split': list(range(2,5,1)),
    'min_samples_leaf': [1,2,3]
}

random_search = RandomizedSearchCV(rf, param_distributions=params, cv=5, scoring='r2')
random_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(),
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': [3, 4, 5, 6, 7],
#                                         'min_samples_leaf': [1, 2, 3],
#                                         'min_samples_split': [2, 3, 4]},
#                    scoring='r2')

# %%
print(random_search.best_params_)
# Out:
# {'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 3, 'max_depth': 20}

# %%
best_rf = random_search.best_estimator_
preds = best_rf.predict(X_test)

# %%
print('R2:', r2_score(y_test, preds))
print('MSE:', mean_squared_error(y_test, preds))
# Out:
# R2: 0.6353207779930248
# MSE: 0.03891471556

# %%
results = pd.DataFrame(y_test)
results['prediction'] = preds
results.index = df_test['Player']
results
# Out:
#                          Share  prediction
# Player
# Joel Embiid              0.915     0.52840
# Nikola Jokić             0.674     0.89915
# Giannis Antetokounmpo    0.606     0.50523
# Jayson Tatum             0.280     0.29767
# Shai Gilgeous-Alexander  0.046     0.10897
# Donovan Mitchell         0.030     0.10897
# Domantas Sabonis         0.027     0.22095
# Luka Dončić              0.010     0.30194
# Stephen Curry            0.005     0.11153
# Jimmy Butler             0.003     0.18775

# %% [markdown]
# ### Create function to determine if MVP winner is correct

# %%
actual = results['Share'].idxmax()
prediction = results['prediction'].idxmax()

# %%
def mvp_prediction(actual, prediction):
    if actual == prediction:
        return 'Correct'
    else:
        return 'Wrong'

# %%
dat = pd.DataFrame()
dat['R2'] = [r2_score(y_test, preds)]
dat['MSE'] = [mean_squared_error(y_test, preds)]
dat['MVP'] = [mvp_prediction(actual, prediction)]
dat.index = [2021]
dat
# Out:
#             R2       MSE    MVP
# 2021  0.595837  0.045659  Wrong

# %% [markdown]
# ### Create function for all evaluations

# %%
def evaluate(y_test, pred):
    evals = []
    results = pd.DataFrame(y_test)
    results['prediction'] = pred
    results.index = df_test['Player']
    actual = results['Share'].idxmax()
    prediction = results['prediction'].idxmax()
    evals.append(r2_score(y_test, pred))
    evals.append(mean_squared_error(y_test, pred))
    evals.append(mvp_prediction(actual, prediction))
    return evals, results

# %% [markdown]
# ### For loop to use each year as a test set

# %%
# empty dict to store results
evals_by_year = {}

best_params_year={}

results_by_year = {}

for year in range(1980, 2024):
    df_train = df[df['Year'] != year]
    df_test = df[df['Year'] == year]
    X_train =  df_train[cols]
    y_train = df_train['Share']
    X_test =  df_test[cols]
    y_test = df_test['Share']
    rf = RandomForestRegressor()
    random_search = RandomizedSearchCV(rf, param_distributions=params, cv=5, scoring='r2')
    random_search.fit(X_train, y_train)
    best_rf = random_search.best_estimator_
    pred = best_rf.predict(X_test)
    eval, results = evaluate(y_test, pred)
    evals_by_year[year] = eval
    results_by_year[year] = results
    best_params_year[year] = random_search.best_params_

# %%
rf_res = pd.DataFrame(list(evals_by_year.values()), index=evals_by_year.keys())
rf_res.columns = ['R2', 'MSE', 'MVP']
rf_res.index.name='Idx'
rf_res.sort_values(by = ['MVP', 'Idx'], ascending = [False, True])
# Out:
#             R2       MSE      MVP
# Idx
# 1982  0.259989  0.036048    Wrong
# 1993  0.740380  0.024919    Wrong
# 1994  0.508675  0.045207    Wrong
# 1998  0.572612  0.043100    Wrong
# 1999 -0.113008  0.083488    Wrong
# 2001  0.337644  0.058758    Wrong
# 2005 -0.265816  0.112268    Wrong
# 2006  0.129022  0.055520    Wrong
# 2008  0.621712  0.037988    Wrong
# 2011  0.377458  0.056669    Wrong
# 2017  0.102204  0.091280    Wrong
# 2023  0.645833  0.037793    Wrong
# 1980  0.801427  0.008024  Correct
# 1981  0.365720  0.032635  Correct
# 1983  0.521473  0.038872  Correct
# 1984  0.519465  0.029806  Correct
# 1985  0.798281  0.013703  Correct
# 1986  0.579233  0.033714  Correct
# 1987  0.736055  0.022232  Correct
# 1988  0.775713  0.020202  Correct
# 1989  0.792183  0.015408  Correct
# 1990  0.705271  0.021534  Correct
# 1991  0.666877  0.027589  Correct
# 1992  0.851823  0.011965  Correct
# 1995  0.746510  0.019028  Correct
# 1996  0.789203  0.017303  Correct
# 1997  0.944437  0.005247  Correct
# 2000  0.888429  0.007795  Correct
# 2002  0.116287  0.074396  Correct
# 2003  0.354504  0.053941  Correct
# 2004  0.586091  0.038676  Correct
# 2007  0.469586  0.051264  Correct
# 2009  0.720220  0.028345  Correct
# 2010  0.697668  0.029000  Correct
# 2012  0.525200  0.043848  Correct
# 2013  0.812449  0.018282  Correct
# 2014  0.746527  0.026247  Correct
# 2015  0.778437  0.021723  Correct
# 2016  0.564110  0.041361  Correct
# 2018  0.754873  0.025224  Correct
# 2019  0.631927  0.036414  Correct
# 2020  0.664441  0.033520  Correct
# 2021  0.774399  0.021635  Correct
# 2022  0.816332  0.018607  Correct

# %%
rf_res['MVP'].value_counts()
# Out:
# Correct    32
# Wrong      12
# Name: MVP, dtype: int64

# %%
rf_res.mean(axis=0)
# Out:
# /var/folders/vv/5y3czrp10w7dkbkrzmk_d70m0000gn/T/ipykernel_95611/4195158480.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   rf_res.mean(axis=0)
# R2     0.577542
# MSE    0.035695
# dtype: float64

# %%
best_params = pd.DataFrame(list(best_params_year.values()), index=best_params_year.keys())
best_params[rf_res['MVP']=='Correct']
# Out:
#       min_samples_split  min_samples_leaf  max_features  max_depth
# 1980                  3                 3             3         15
# 1981                  2                 3             6          5
# 1983                  3                 3             7         15
# 1984                  4                 2             4          5
# 1985                  4                 2             3         15
# 1986                  3                 3             6         25
# 1987                  4                 3             5          5
# 1988                  4                 3             4          5
# 1989                  3                 3             4          5
# 1990                  4                 3             5         25
# 1991                  2                 3             4         10
# 1992                  4                 2             6          5
# 1995                  3                 2             6         30
# 1996                  3                 1             3         10
# 1997                  3                 2             6          5
# 2000                  3                 1             7          5
# 2002                  4                 2             5         10
# 2003                  2                 3             3          5
# 2004                  3                 3             4         25
# 2007                  3                 2             4          5
# 2009                  2                 3             3         20
# 2010                  2                 3             3         15
# 2012                  2                 1             3         30
# 2013                  3                 1             4         20
# 2014                  4                 3             3         15
# 2015                  4                 3             7          5
# 2016                  3                 2             3         20
# 2018                  4                 1             5         15
# 2019                  4                 1             3          5
# 2020                  2                 1             6          5
# 2021                  2                 3             5         20
# 2022                  3                 2             6         30

# %%
for c in best_params.columns:
    print(best_params[rf_res['MVP']=='Correct'][c].value_counts())
# Out:
# 3    13
# 4    11
# 2     8
# Name: min_samples_split, dtype: int64
# 3    16
# 2     9
# 1     7
# Name: min_samples_leaf, dtype: int64
# 3    10
# 6     7
# 4     7
# 5     5
# 7     3
# Name: max_features, dtype: int64
# 5     13
# 15     6
# 20     4
# 25     3
# 10     3
# 30     3
# Name: max_depth, dtype: int64

# %% [markdown]
# ### Test all years with most frequently used hyperparameters

# %%
# empty dict to store results
evals_by_year = {}

results_by_year = {}

for year in range(1980, 2024):
    df_train = df[df['Year'] != year]
    df_test = df[df['Year'] == year]
    X_train =  df_train[cols]
    y_train = df_train['Share']
    X_test =  df_test[cols]
    y_test = df_test['Share']
    rf = RandomForestRegressor(min_samples_split=3, min_samples_leaf=3, max_features=3, max_depth=5)
    rf.fit(X_train, y_train)
    pred = rf.predict(X_test)
    eval, results = evaluate(y_test, pred)
    evals_by_year[year] = eval
    results_by_year[year] = results

# %%
rf_res = pd.DataFrame(list(evals_by_year.values()), index=evals_by_year.keys())
rf_res.columns = ['R2', 'MSE', 'MVP']
rf_res.index.name='Idx'
rf_res.sort_values(by = ['MVP', 'Idx'], ascending = [False, True])
# Out:
#             R2       MSE      MVP
# Idx
# 1982  0.218240  0.038082    Wrong
# 1989  0.743293  0.019033    Wrong
# 1993  0.723333  0.026555    Wrong
# 1994  0.540062  0.042319    Wrong
# 1997  0.924900  0.007092    Wrong
# 1998  0.562427  0.044128    Wrong
# 1999 -0.070407  0.080293    Wrong
# 2001  0.160037  0.074514    Wrong
# 2005 -0.187169  0.105292    Wrong
# 2006  0.148095  0.054304    Wrong
# 2008  0.560095  0.044175    Wrong
# 2011  0.285367  0.065052    Wrong
# 2017  0.179694  0.083401    Wrong
# 2023  0.577656  0.045068    Wrong
# 1980  0.774118  0.009128  Correct
# 1981  0.261683  0.037988  Correct
# 1983  0.546874  0.036808  Correct
# 1984  0.436312  0.034964  Correct
# 1985  0.834183  0.011264  Correct
# 1986  0.524944  0.038064  Correct
# 1987  0.762093  0.020039  Correct
# 1988  0.789570  0.018954  Correct
# 1990  0.758778  0.017624  Correct
# 1991  0.712332  0.023824  Correct
# 1992  0.861326  0.011198  Correct
# 1995  0.666007  0.025070  Correct
# 1996  0.874617  0.010292  Correct
# 2000  0.894009  0.007405  Correct
# 2002  0.234293  0.064461  Correct
# 2003  0.352707  0.054091  Correct
# 2004  0.625605  0.034984  Correct
# 2007  0.478514  0.050401  Correct
# 2009  0.715704  0.028803  Correct
# 2010  0.683331  0.030376  Correct
# 2012  0.507684  0.045465  Correct
# 2013  0.817967  0.017744  Correct
# 2014  0.741393  0.026779  Correct
# 2015  0.723905  0.027070  Correct
# 2016  0.576336  0.040201  Correct
# 2018  0.763085  0.024379  Correct
# 2019  0.627634  0.036838  Correct
# 2020  0.645879  0.035374  Correct
# 2021  0.755515  0.023446  Correct
# 2022  0.855227  0.014666  Correct

# %%
rf_res['MVP'].value_counts()
# Out:
# Correct    30
# Wrong      14
# Name: MVP, dtype: int64

# %%
rf_res.mean(axis=0)
# Out:
# /var/folders/vv/5y3czrp10w7dkbkrzmk_d70m0000gn/T/ipykernel_95611/4195158480.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   rf_res.mean(axis=0)
# R2     0.571983
# MSE    0.036068
# dtype: float64

# %% [markdown]
# ### Test without years 1982, 1999, 2005, 2006

# %%
drop_yrs = [1982, 1999, 2005, 2006]
mask = ~df['Year'].isin(drop_yrs)
df1 = df[mask]
yrs = range(1980, 2024)
yrs = [y for y in yrs if y not in drop_yrs]
#yrs

# %%
# empty dict to store results
evals_by_year = {}

best_params_year={}

results_by_year={}

for year in yrs:
    df_train = df1[df1['Year'] != year]
    df_test = df1[df1['Year'] == year]
    X_train =  df_train[cols]
    y_train = df_train['Share']
    X_test =  df_test[cols]
    y_test = df_test['Share']
    rf = RandomForestRegressor()
    random_search = RandomizedSearchCV(rf, param_distributions=params, cv=5, scoring='r2')
    random_search.fit(X_train, y_train)
    best_rf = random_search.best_estimator_
    pred = best_rf.predict(X_test)
    eval, results = evaluate(y_test, pred)
    evals_by_year[year] = eval
    results_by_year[year] = results
    best_params_year[year] = random_search.best_params_

# %%
rf_res = pd.DataFrame(list(evals_by_year.values()), index=evals_by_year.keys())
rf_res.columns = ['R2', 'MSE', 'MVP']
rf_res.index.name='Idx'
rf_res.sort_values(by = ['MVP', 'Idx'], ascending = [False, True])
# Out:
#             R2       MSE      MVP
# Idx
# 1983  0.535506  0.037732    Wrong
# 1989  0.823336  0.013098    Wrong
# 1994  0.564102  0.040107    Wrong
# 1997  0.953533  0.004388    Wrong
# 1998  0.650828  0.035213    Wrong
# 2001  0.437666  0.049885    Wrong
# 2008  0.571980  0.042982    Wrong
# 2011  0.307392  0.063048    Wrong
# 2023  0.655954  0.036713    Wrong
# 1980  0.715153  0.011510  Correct
# 1981  0.576252  0.021803  Correct
# 1984  0.464621  0.033208  Correct
# 1985  0.840905  0.010808  Correct
# 1986  0.548510  0.036176  Correct
# 1987  0.763667  0.019907  Correct
# 1988  0.843431  0.014103  Correct
# 1990  0.707421  0.021377  Correct
# 1991  0.739827  0.021547  Correct
# 1992  0.866922  0.010746  Correct
# 1993  0.740571  0.024900  Correct
# 1995  0.801566  0.014895  Correct
# 1996  0.819984  0.014776  Correct
# 2000  0.895500  0.007301  Correct
# 2002  0.286555  0.060062  Correct
# 2003  0.356261  0.053794  Correct
# 2004  0.620034  0.035505  Correct
# 2007  0.372509  0.060647  Correct
# 2009  0.696755  0.030722  Correct
# 2010  0.620595  0.036393  Correct
# 2012  0.500057  0.046170  Correct
# 2013  0.793035  0.020174  Correct
# 2014  0.728698  0.028093  Correct
# 2015  0.731262  0.026349  Correct
# 2016  0.601981  0.037767  Correct
# 2017  0.156337  0.085776  Correct
# 2018  0.788705  0.021742  Correct
# 2019  0.663009  0.033339  Correct
# 2020  0.758542  0.024120  Correct
# 2021  0.764333  0.022600  Correct
# 2022  0.837788  0.016433  Correct

# %%
rf_res['MVP'].value_counts()
# Out:
# Correct    31
# Wrong       9
# Name: MVP, dtype: int64

# %%
rf_res.mean(axis=0)
# Out:
# /var/folders/vv/5y3czrp10w7dkbkrzmk_d70m0000gn/T/ipykernel_95611/4195158480.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   rf_res.mean(axis=0)
# R2     0.652527
# MSE    0.030648
# dtype: float64

# %%
best_params = pd.DataFrame(list(best_params_year.values()), index=best_params_year.keys())
for c in best_params.columns:
    print(best_params[rf_res['MVP']=='Correct'][c].value_counts())
# Out:
# 2    12
# 3    12
# 4     7
# Name: min_samples_split, dtype: int64
# 2    16
# 3     8
# 1     7
# Name: min_samples_leaf, dtype: int64
# 3    19
# 4     8
# 6     2
# 5     1
# 7     1
# Name: max_features, dtype: int64
# 25    7
# 30    7
# 15    6
# 10    5
# 20    4
# 5     2
# Name: max_depth, dtype: int64

# %%
best_params
# Out:
#       min_samples_split  min_samples_leaf  max_features  max_depth
# 1980                  2                 1             4         20
# 1981                  2                 1             3         10
# 1983                  3                 2             3         25
# 1984                  2                 1             3         15
# 1985                  4                 2             4         25
# 1986                  2                 2             4         10
# 1987                  2                 3             3         15
# 1988                  4                 2             3         30
# 1989                  4                 2             4         20
# 1990                  3                 3             4         30
# 1991                  2                 3             3         25
# 1992                  3                 3             4         25
# 1993                  2                 2             3         30
# 1994                  2                 1             3         30
# 1995                  4                 2             3         15
# 1996                  3                 2             3         30
# 1997                  3                 2             4          5
# 1998                  4                 2             3         10
# 2000                  4                 2             5         30
# 2001                  2                 3             3         25
# 2002                  3                 3             3         20
# 2003                  2                 2             3         15
# 2004                  2                 2             3         25
# 2007                  3                 2             6         25
# 2008                  4                 3             5         10
# 2009                  3                 2             4         15
# 2010                  4                 2             3         20
# 2011                  2                 3             3         15
# 2012                  3                 1             3         25
# 2013                  3                 3             3         10
# 2014                  4                 2             3         30
# 2015                  3                 2             4         25
# 2016                  2                 2             6          5
# 2017                  3                 1             3         30
# 2018                  2                 1             3         10
# 2019                  2                 3             7         20
# 2020                  4                 1             4          5
# 2021                  3                 2             3         15
# 2022                  3                 3             3         10
# 2023                  3                 2             3         15

# %%
results_by_year[2022]
# Out:
#                        Share  prediction
# Player
# Nikola Jokić           0.875    0.728056
# Joel Embiid            0.706    0.496549
# Giannis Antetokounmpo  0.595    0.670634
# Devin Booker           0.216    0.188041
# Luka Dončić            0.146    0.268830
# Jayson Tatum           0.043    0.160157
# Ja Morant              0.010    0.235764
# Stephen Curry          0.004    0.088716
# Chris Paul             0.002    0.058742
# DeMar DeRozan          0.001    0.047779

# %% [markdown]
# ### Test all years with best hyperparameters

# %%
# empty dict to store results
evals_by_year = {}

results_by_year={}

for year in yrs:
    df_train = df1[df1['Year'] != year]
    df_test = df1[df1['Year'] == year]
    X_train =  df_train[cols]
    y_train = df_train['Share']
    X_test =  df_test[cols]
    y_test = df_test['Share']
    rf = RandomForestRegressor(min_samples_split=2, min_samples_leaf=2, max_features=3, max_depth=30, random_state=0)
    rf.fit(X_train, y_train)
    pred = rf.predict(X_test)
    eval, results = evaluate(y_test, pred)
    evals_by_year[year] = eval
    results_by_year[year] = results

# %%
rf_res = pd.DataFrame(list(evals_by_year.values()), index=evals_by_year.keys())
rf_res.columns = ['R2', 'MSE', 'MVP']
rf_res.index.name='Idx'
rf_res.sort_values(by = ['MVP', 'Idx'], ascending = [False, True])
# Out:
#             R2       MSE      MVP
# Idx
# 1989  0.779716  0.016333    Wrong
# 1994  0.580091  0.038636    Wrong
# 1998  0.638401  0.036466    Wrong
# 2001  0.392399  0.053901    Wrong
# 2008  0.658190  0.034325    Wrong
# 2011  0.326811  0.061280    Wrong
# 2017  0.086956  0.092830    Wrong
# 2023  0.612330  0.041368    Wrong
# 1980  0.808957  0.007720  Correct
# 1981  0.532202  0.024069  Correct
# 1983  0.480764  0.042179  Correct
# 1984  0.423072  0.035785  Correct
# 1985  0.788266  0.014383  Correct
# 1986  0.604395  0.031698  Correct
# 1987  0.733368  0.022459  Correct
# 1988  0.815121  0.016653  Correct
# 1990  0.716474  0.020715  Correct
# 1991  0.766092  0.019372  Correct
# 1992  0.865602  0.010852  Correct
# 1993  0.736427  0.025298  Correct
# 1995  0.766196  0.017550  Correct
# 1996  0.761705  0.019560  Correct
# 1997  0.950157  0.004707  Correct
# 2000  0.877670  0.008547  Correct
# 2002  0.289628  0.059803  Correct
# 2003  0.343956  0.054822  Correct
# 2004  0.629658  0.034605  Correct
# 2007  0.319207  0.065798  Correct
# 2009  0.680704  0.032349  Correct
# 2010  0.642640  0.034279  Correct
# 2012  0.587068  0.038134  Correct
# 2013  0.793999  0.020080  Correct
# 2014  0.767557  0.024069  Correct
# 2015  0.752312  0.024285  Correct
# 2016  0.591501  0.038762  Correct
# 2018  0.771921  0.023470  Correct
# 2019  0.645714  0.035050  Correct
# 2020  0.821025  0.017878  Correct
# 2021  0.820369  0.017226  Correct
# 2022  0.877260  0.012434  Correct

# %%
rf_res['MVP'].value_counts()
# Out:
# Correct    32
# Wrong       8
# Name: MVP, dtype: int64

# %%
rf_res.mean(axis=0)
# Out:
# /var/folders/vv/5y3czrp10w7dkbkrzmk_d70m0000gn/T/ipykernel_95611/4195158480.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   rf_res.mean(axis=0)
# R2     0.650897
# MSE    0.030743
# dtype: float64

# %%
results_by_year[2011]
# Out:
#                    Share  prediction
# Player
# Derrick Rose       0.977    0.387933
# Dwight Howard      0.531    0.195147
# LeBron James       0.431    0.622994
# Kobe Bryant        0.354    0.089448
# Kevin Durant       0.157    0.120868
# Dirk Nowitzki      0.093    0.139885
# Dwyane Wade        0.020    0.205628
# Manu Ginóbili      0.017    0.081133
# Amar'e Stoudemire  0.007    0.043025
# Blake Griffin      0.004    0.056712

# %%
# save dict of best results
filehandler = open('rf_results_year.pkl', 'wb')
pickle.dump(results_by_year, filehandler)

# %% [markdown]
# ### Train model with best results and entire data, save model

# %%
X =  df1[cols]
y = df1['Share']

# %%
rf_best = RandomForestRegressor(min_samples_split=2, min_samples_leaf=2, max_features=3, max_depth=30, random_state=0)
rf_best.fit(X,y)
# Out:
# RandomForestRegressor(max_depth=30, max_features=3, min_samples_leaf=2,
#                       random_state=0)

# %%
joblib.dump(rf_best, "./rf_best.joblib")
# Out:
# ['./rf_best.joblib']

# %%
cols
# Out:
# ['PRA',
#  'WS/48',
#  'player_efficiency_rating',
#  'offensive_box_plus_minus',
#  'value_over_replacement_player',
#  'wl_pct',
#  'seed']
